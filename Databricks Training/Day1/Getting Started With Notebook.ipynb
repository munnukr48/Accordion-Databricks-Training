# %% [markdown]
# **Databricks Notebook**

# %%
print("Hello Databricks")

# %%
# %sql
Select "Hello"

# %%
# %sql
create schema if not exists acc_dev.Munnu

# %%
# %sql
--drop table acc_dev.munnu.demo;
create table acc_dev.munnu.demo
(
  id int primary key,
  name string
)

# %%
# %sql
select * from acc_dev.munnu.demo

# %%
# %sql
create volume if not exists acc_dev.Munnu.raw

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)

# %%
# %sql
Select * from acc_dev.munnu.sales
