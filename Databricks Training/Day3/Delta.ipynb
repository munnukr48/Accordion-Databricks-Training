-- %%
%sql
use catalog acc_dev;
use schema munnu;

-- %%
create table if not exists emp(id int, name string, city string)

-- %%
insert into acc_dev.naval.emp values (5,'CK','Patna')

-- %%
Select * from emp

-- %%
describe table emp

-- %%
DESCRIBE HISTORY emp

-- %%
desc extended emp

-- %%
delete from emp where id=1

-- %%
update emp set name='KC' where id=1

-- %%
select * from emp version as of 4

-- %%
--restore table emp to version as of 3
select * from emp
